# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file = "JODI Data.csv"
jodi_df = pd.read_csv(csv_file, skiprows=4)
jodi_df
# Out:
#                          Time     2014-02     2014-03     2014-04     2014-05  \
# 0                     Country         NaN         NaN         NaN         NaN
# 1                     Albania      0.0000      0.0000      0.0000      0.0000
# 2                     Algeria   1269.0000   1217.0000   1204.0000   1204.0000
# 3                      Angola   1600.0000   1446.0000   1599.0000   1605.0000
# 4                   Argentina    534.2857    531.1935    511.3000    501.0645
# 5                     Armenia      0.0000      0.0000      0.0000      0.0000
# 6                   Australia    359.0491    341.3442    321.4452    313.6195
# 7                     Austria     17.3560     18.6299     17.6075     18.1755
# 8                  Azerbaijan    803.8564    807.8471    836.2493    827.3419
# 9                     Bahrain     49.4843     50.6390     48.6420     49.4503
# 10                 Bangladesh      0.0000      0.0000      0.0000      0.0000
# ...

# %%
jodi_df=jodi_df.dropna(axis=0)
jodi_df.head()
# Out:
#         Time    2014-02    2014-03  2014-04    2014-05    2014-06    2014-07  \
# 1    Albania     0.0000     0.0000      0.0     0.0000     0.0000     0.0000
# 2    Algeria  1269.0000  1217.0000   1204.0  1204.0000  1204.0000  1217.0000
# 3     Angola  1600.0000  1446.0000   1599.0  1605.0000  1645.0000  1714.0000
# 4  Argentina   534.2857   531.1935    511.3   501.0645   532.3333   522.0645
# 5    Armenia     0.0000     0.0000      0.0     0.0000     0.0000     0.0000
#
#      2014-08    2014-09    2014-10  ...    2018-05  2018-06    2018-07  \
# 1     0.0000     0.0000     0.0000  ...     0.0000      0.0     0.0000
# 2  1216.0000  1197.0000  1188.0000  ...  1040.0000   1054.0  1064.0000
# 3  1709.0000  1703.0000  1751.0000  ...  1486.0000   1448.0  1455.0000
# 4   525.4194   528.8667   535.2258  ...   481.7742    481.7   480.4194
# 5     0.0000     0.0000     0.0000  ...     0.0000      0.0     0.0000
#
# ...

# %%
#jodi_df.columns = jodi_df.iloc[0]
# jodi_df = jodi_df.reindex()
#jodi_df.head()

# %%
jodi_df.reset_index(drop=True,inplace=True)

# %%
jodi_df.rename(columns=
              {"Time": "Country"},inplace=True)
jodi_df
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#                       Country     2014-02     2014-03     2014-04     2014-05  \
# 0                     Albania      0.0000      0.0000      0.0000      0.0000
# 1                     Algeria   1269.0000   1217.0000   1204.0000   1204.0000
# 2                      Angola   1600.0000   1446.0000   1599.0000   1605.0000
# 3                   Argentina    534.2857    531.1935    511.3000    501.0645
# 4                     Armenia      0.0000      0.0000      0.0000      0.0000
# 5                   Australia    359.0491    341.3442    321.4452    313.6195
# 6                     Austria     17.3560     18.6299     17.6075     18.1755
# ...

# %% [markdown]
# ### Create new data with select columns

# %%
new_jodi_df = jodi_df[['id', 'first_name', 'last_name']].copy()
new_jodi_df.head()

# %% [markdown]
# ### Store JSON data into a DataFrame

# %%
json_file = "../Resources/customer_location.json"
customer_location_df = pd.read_json(json_file)
customer_location_df.head()

# %% [markdown]
# ### Clean DataFrame

# %%
new_customer_location_df = customer_location_df[["id", "address", "us_state"]].copy()
new_customer_location_df.head()

# %% [markdown]
# ### Connect to local database

# %%
rds_connection_string = "<insert user name>:<insert password>@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
new_customer_data_df.to_sql(name='customer_name', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Use pandas to load json converted DataFrame into database

# %%
new_customer_location_df.to_sql(name='customer_location', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the customer_name table
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('select * from customer_name', con=engine).head()

# %% [markdown]
# ### Confirm data has been added by querying the customer_location table

# %%
pd.read_sql_query('select * from customer_location', con=engine).head()
