# %%
# Dependencies
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import requests
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()


url = "https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=CL&apikey=OXORD93CJRCKNW7W"
format = "json"

# Get country information in JSON format
data = requests.get(f"{url}countries?format=json").json()

# First element is general information, second is countries themselves
#data

# %%
# Here is your API key: OXORD93CJRCKNW7W. Please record this API key for future access to Alpha Vantage.

# %%
data.keys()
# Out:
# dict_keys(['Meta Data', 'Monthly Time Series'])

# %%
data["Monthly Time Series"]

data.keys()

time_series = data["Monthly Time Series"]

dates = time_series.keys()

df = pd.DataFrame(time_series)
df = df.astype(float)

# %%
df.head()
# Out:
#             2019-05-07   2019-04-30    2019-03-29   2019-02-28    2019-01-31  \
# 1. open          72.08        68.38  6.592000e+01        64.90  5.924000e+01
# 2. high          72.47        72.85  6.860690e+01        67.47  6.485000e+01
# 3. low           69.55        67.25  6.478000e+01        64.20  5.862000e+01
# 4. close         70.51        72.79  6.854000e+01        65.87  6.468000e+01
# 5. volume  14861310.00  67311179.00  7.109046e+07  72086027.00  1.044044e+08
#
#              2018-12-31    2018-11-30    2018-10-31   2018-09-28   2018-08-31  \
# 1. open    6.346000e+01  5.963000e+01  6.696000e+01        65.74        66.83
# 2. high    6.588000e+01  6.398500e+01  6.780000e+01        69.29        68.43
# 3. low     5.750500e+01  5.932000e+01  5.741000e+01        64.95        65.01
# 4. close   5.952000e+01  6.352000e+01  5.955000e+01        66.95        66.41
# 5. volume  1.000546e+08  1.095778e+08  1.188532e+08  57660645.00  64553153.00
#
# ...

# %%
df_price = df.drop(['1. open','4. close','5. volume'])

# %%
df_price.loc['mean'] = df_price.mean()

# %%
df_price.head()
# Out:
#          2019-05-07  2019-04-30  2019-03-29  2019-02-28  2019-01-31  \
# 2. high       72.47       72.85    68.60690      67.470      64.850
# 3. low        69.55       67.25    64.78000      64.200      58.620
# mean          71.01       70.05    66.69345      65.835      61.735
#
#          2018-12-31  2018-11-30  2018-10-31  2018-09-28  2018-08-31  \
# 2. high     65.8800     63.9850      67.800       69.29       68.43
# 3. low      57.5050     59.3200      57.410       64.95       65.01
# mean        61.6925     61.6525      62.605       67.12       66.72
#
#             ...      1998-11-30  1998-10-30  1998-09-30  1998-08-31  \
# 2. high     ...           95.00      90.000       77.00      93.310
# 3. low      ...           85.50      67.130       65.06      71.880
# mean        ...           90.25      78.565       71.03      82.595
#
#          1998-07-31  1998-06-30  1998-05-29  1998-04-30  1998-03-31  \
# 2. high      98.880      92.130       91.00        91.5      88.880
# ...

# %%
new_cols = [date[:-3] for date in df_price.columns]
#new_cols

# %%
df_price.columns = new_cols
df_price
# Out:
#          2019-05  2019-04   2019-03  2019-02  2019-01  2018-12  2018-11  \
# 2. high    72.47    72.85  68.60690   67.470   64.850  65.8800  63.9850
# 3. low     69.55    67.25  64.78000   64.200   58.620  57.5050  59.3200
# mean       71.01    70.05  66.69345   65.835   61.735  61.6925  61.6525
#
#          2018-10  2018-09  2018-08   ...     1998-11  1998-10  1998-09  \
# 2. high   67.800    69.29    68.43   ...       95.00   90.000    77.00
# 3. low    57.410    64.95    65.01   ...       85.50   67.130    65.06
# mean      62.605    67.12    66.72   ...       90.25   78.565    71.03
#
#          1998-08  1998-07  1998-06  1998-05  1998-04  1998-03  1998-02
# 2. high   93.310   98.880   92.130    91.00     91.5   88.880    81.81
# 3. low    71.880   87.750   84.940    84.88     81.5   78.630    73.25
# mean      82.595   93.315   88.535    87.94     86.5   83.755    77.53
#
# [3 rows x 256 columns]

# %%
#df_price.replace("","country")
df_price.rename(columns= {"": "Country"}, inplace=True)
df_price
# Out:
#          2019-05  2019-04   2019-03  2019-02  2019-01  2018-12  2018-11  \
# 2. high    72.47    72.85  68.60690   67.470   64.850  65.8800  63.9850
# 3. low     69.55    67.25  64.78000   64.200   58.620  57.5050  59.3200
# mean       71.01    70.05  66.69345   65.835   61.735  61.6925  61.6525
#
#          2018-10  2018-09  2018-08   ...     1998-11  1998-10  1998-09  \
# 2. high   67.800    69.29    68.43   ...       95.00   90.000    77.00
# 3. low    57.410    64.95    65.01   ...       85.50   67.130    65.06
# mean      62.605    67.12    66.72   ...       90.25   78.565    71.03
#
#          1998-08  1998-07  1998-06  1998-05  1998-04  1998-03  1998-02
# 2. high   93.310   98.880   92.130    91.00     91.5   88.880    81.81
# 3. low    71.880   87.750   84.940    84.88     81.5   78.630    73.25
# mean      82.595   93.315   88.535    87.94     86.5   83.755    77.53
#
# [3 rows x 256 columns]

# %%
csv_file = "JODI Data.csv"
df_production = pd.read_csv(csv_file, skiprows=4)
df_production
# Out:
#                          Time     2014-02     2014-03     2014-04     2014-05  \
# 0                     Country         NaN         NaN         NaN         NaN
# 1                     Albania      0.0000      0.0000      0.0000      0.0000
# 2                     Algeria   1269.0000   1217.0000   1204.0000   1204.0000
# 3                      Angola   1600.0000   1446.0000   1599.0000   1605.0000
# 4                   Argentina    534.2857    531.1935    511.3000    501.0645
# 5                     Armenia      0.0000      0.0000      0.0000      0.0000
# 6                   Australia    359.0491    341.3442    321.4452    313.6195
# 7                     Austria     17.3560     18.6299     17.6075     18.1755
# 8                  Azerbaijan    803.8564    807.8471    836.2493    827.3419
# 9                     Bahrain     49.4843     50.6390     48.6420     49.4503
# 10                 Bangladesh      0.0000      0.0000      0.0000      0.0000
# ...

# %%
df_production=df_production.dropna(axis=0)
df_production.head()
# Out:
#         Time    2014-02    2014-03  2014-04    2014-05    2014-06    2014-07  \
# 1    Albania     0.0000     0.0000      0.0     0.0000     0.0000     0.0000
# 2    Algeria  1269.0000  1217.0000   1204.0  1204.0000  1204.0000  1217.0000
# 3     Angola  1600.0000  1446.0000   1599.0  1605.0000  1645.0000  1714.0000
# 4  Argentina   534.2857   531.1935    511.3   501.0645   532.3333   522.0645
# 5    Armenia     0.0000     0.0000      0.0     0.0000     0.0000     0.0000
#
#      2014-08    2014-09    2014-10   ...       2018-05  2018-06    2018-07  \
# 1     0.0000     0.0000     0.0000   ...        0.0000      0.0     0.0000
# 2  1216.0000  1197.0000  1188.0000   ...     1040.0000   1054.0  1064.0000
# 3  1709.0000  1703.0000  1751.0000   ...     1486.0000   1448.0  1455.0000
# 4   525.4194   528.8667   535.2258   ...      481.7742    481.7   480.4194
# 5     0.0000     0.0000     0.0000   ...        0.0000      0.0     0.0000
#
# ...

# %%
df_production.reset_index(drop=True,inplace=True)
df_production.rename(columns=
              {"Time": "Country"},inplace=True)
df_production.head()
# Out:
# C:\Users\hocin\Anaconda\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#      Country    2014-02    2014-03  2014-04    2014-05    2014-06    2014-07  \
# 0    Albania     0.0000     0.0000      0.0     0.0000     0.0000     0.0000
# 1    Algeria  1269.0000  1217.0000   1204.0  1204.0000  1204.0000  1217.0000
# 2     Angola  1600.0000  1446.0000   1599.0  1605.0000  1645.0000  1714.0000
# 3  Argentina   534.2857   531.1935    511.3   501.0645   532.3333   522.0645
# 4    Armenia     0.0000     0.0000      0.0     0.0000     0.0000     0.0000
#
#      2014-08    2014-09    2014-10   ...       2018-05  2018-06    2018-07  \
# 0     0.0000     0.0000     0.0000   ...        0.0000      0.0     0.0000
# ...

# %%
df_production.set_index('Country', inplace=True)
df_production
# Out:
#                              2014-02     2014-03     2014-04     2014-05  \
# Country
# Albania                       0.0000      0.0000      0.0000      0.0000
# Algeria                    1269.0000   1217.0000   1204.0000   1204.0000
# Angola                     1600.0000   1446.0000   1599.0000   1605.0000
# Argentina                   534.2857    531.1935    511.3000    501.0645
# Armenia                       0.0000      0.0000      0.0000      0.0000
# Australia                   359.0491    341.3442    321.4452    313.6195
# Austria                      17.3560     18.6299     17.6075     18.1755
# Azerbaijan                  803.8564    807.8471    836.2493    827.3419
# Bahrain                      49.4843     50.6390     48.6420     49.4503
# Bangladesh                    0.0000      0.0000      0.0000      0.0000
# Barbados                      0.0000      0.0000      0.0000      0.0000
# Belarus                      33.3693     33.4625     33.1065     33.2252
# ...

# %%
frames = [df_price,df_production]
df_data = pd.concat(frames)

df_data
# Out:
# C:\Users\hocin\Anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                           1998-02  1998-03  1998-04  1998-05  1998-06  \
# 2. high                     81.81   88.880     91.5    91.00   92.130
# 3. low                      73.25   78.630     81.5    84.88   84.940
# mean                        77.53   83.755     86.5    87.94   88.535
# Albania                       NaN      NaN      NaN      NaN      NaN
# Algeria                       NaN      NaN      NaN      NaN      NaN
# Angola                        NaN      NaN      NaN      NaN      NaN
# Argentina                     NaN      NaN      NaN      NaN      NaN
# Armenia                       NaN      NaN      NaN      NaN      NaN
# ...

# %%
df_data = df_data.dropna(axis = 1)
df_data
# Out:
#                              2014-02     2014-03     2014-04     2014-05  \
# 2. high                      63.1500     65.9200     67.9500     69.8050
# 3. low                       59.7500     62.0000     63.8700     66.1000
# mean                         61.4500     63.9600     65.9100     67.9525
# Albania                       0.0000      0.0000      0.0000      0.0000
# Algeria                    1269.0000   1217.0000   1204.0000   1204.0000
# Angola                     1600.0000   1446.0000   1599.0000   1605.0000
# Argentina                   534.2857    531.1935    511.3000    501.0645
# Armenia                       0.0000      0.0000      0.0000      0.0000
# Australia                   359.0491    341.3442    321.4452    313.6195
# Austria                      17.3560     18.6299     17.6075     18.1755
# Azerbaijan                  803.8564    807.8471    836.2493    827.3419
# Bahrain                      49.4843     50.6390     48.6420     49.4503
# ...

# %%
#connect to database 
engine = create_engine("mysql://root:J****2028@localhost/oilprod_db")

# load the dataframe into oilprod_db sql data base 

df_data.to_sql('oil_prod_price',engine, if_exists = 'append', index=False)
